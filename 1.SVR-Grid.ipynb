# %%
#importing the libaries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the dataset
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400        True     False      False
# 1      18  33.770         1   1725.55230       False      True       True
# 2      28  33.000         3   4449.46200       False      True       True
# 3      33  22.705         0  21984.47061       False      True       True
# 4      32  28.880         0   3866.85520       False      True       True
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830       False      True       True
# 1334   18  31.920         0   2205.98080        True     False       True
# 1335   18  36.850         0   1629.83350        True     False       True
# 1336   21  25.800         0   2007.94500        True     False       True
# 1337   61  29.070         0  29141.36030        True     False      False
#
#       smoker_yes
# 0           True
# 1          False
# 2          False
# ...

# %%
dataset = dataset.astype({
    'sex_female': int,
    'sex_male': int,
    'smoker_no': int,
    'smoker_yes': int,
})

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes
# 0              1
# 1              0
# 2              0
# ...

# %%
dataset = pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes
# 0              1
# 1              0
# 2              0
# ...

# %%
dataset.drop(columns=['sex_female'], inplace=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_no  smoker_yes
# 0      19  27.900         0  16884.92400         0          0           1
# 1      18  33.770         1   1725.55230         1          1           0
# 2      28  33.000         3   4449.46200         1          1           0
# 3      33  22.705         0  21984.47061         1          1           0
# 4      32  28.880         0   3866.85520         1          1           0
# ...   ...     ...       ...          ...       ...        ...         ...
# 1333   50  30.970         3  10600.54830         1          1           0
# 1334   18  31.920         0   2205.98080         0          1           0
# 1335   18  36.850         0   1629.83350         0          1           0
# 1336   21  25.800         0   2007.94500         0          1           0
# 1337   61  29.070         0  29141.36030         0          0           1
#
# [1338 rows x 7 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_no',
#        'smoker_yes'],
#       dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_no',
       'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_no  smoker_yes
# 0      19  27.900         0         0          0           1
# 1      18  33.770         1         1          1           0
# 2      28  33.000         3         1          1           0
# 3      33  22.705         0         1          1           0
# 4      32  28.880         0         1          1           0
# ...   ...     ...       ...       ...        ...         ...
# 1333   50  30.970         3         1          1           0
# 1334   18  31.920         0         0          1           0
# 1335   18  36.850         0         0          1           0
# 1336   21  25.800         0         0          1           0
# 1337   61  29.070         0         0          0           1
#
# [1338 rows x 6 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
#split into training  set and test
X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=1/3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','ploy','sigmoid','linear'],'C':[10, 100, 1000, 2000, 3000],'gamma':['auto','scale']}
grid = GridSearchCV(SVR(), param_grid, refit= True, verbose= 3, n_jobs=-1)

# fitting the model for gridsearch
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# E:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 50 fits failed out of a total of 200.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\anaconda3\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
# ...

# %%
# print best parameter after tuning
print (grid.best_params_)
re=grid.cv_results_
print("The R_Score value for best parameter {}:".format(grid.best_params_))
# Out:
# {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}
# The R_Score value for best parameter {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.597568      0.215632         0.169281        0.055129       10
# 1        0.008206      0.004835         0.000000        0.000000       10
# 2        0.423253      0.147391         0.071036        0.020139       10
# 3        0.253896      0.019408         0.058512        0.016607       10
# 4        0.386392      0.081060         0.200503        0.020150       10
# 5        0.006523      0.003126         0.000000        0.000000       10
# 6        0.544519      0.057960         0.108525        0.034837       10
# 7        0.364580      0.029753         0.035488        0.008066       10
# 8        0.431439      0.046793         0.208974        0.019984      100
# 9        0.004126      0.002456         0.000000        0.000000      100
# 10       0.562497      0.088307         0.101498        0.043936      100
# 11       0.443495      0.071965         0.068673        0.032234      100
# ...

# %%
age_input = float(input("Age: "))
bmi_input = float(input("BMI: "))
children_input = float(input("Children: "))
sex_male_input = int(input("Sex Male (0 or 1): "))
smoker_yes_input = int(input("Smoker Yes (0 or 1): "))
# Out:
# Age:  32
# BMI:  43
# Children:  2
# Sex Male (0 or 1):  0
# Smoker Yes (0 or 1):  1

# %%
print(independent.columns)
# Out:
# Index(['age', 'bmi', 'children', 'sex_male', 'smoker_no', 'smoker_yes'], dtype='object')

# %%
sex_female_input = 1 - sex_male_input

Future_Prediction = grid.predict([[
    age_input,
    bmi_input,
    children_input,
    sex_male_input,
    smoker_yes_input,
    sex_female_input
]])

print(Future_Prediction)
# Out:
# [17126.11013289]
